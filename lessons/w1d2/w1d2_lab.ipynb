# %% [markdown]
# <div dir="rtl">
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hanenalmayouf/Content-creator-dashdoard/blob/main/lessons/w1d2/w1d2_lab.ipynb)
#
# # تخزين البيانات: مستودعات البيانات وبحيرات البيانات
# ### تحليل متعمق لأنظمة تخزين البيانات الهيكلية وغير الهيكلية ومقارنة تقنيات التخزين السحابي.
# </div>

# %% [markdown]
# <div dir="rtl">
# # معمل: تخزين البيانات: مستودعات البيانات وبحيرات البيانات
# تحليل متعمق لأنظمة تخزين البيانات الهيكلية وغير الهيكلية ومقارنة تقنيات التخزين السحابي.
#
# ### أهداف المعمل:
# - مقارنة بين Data Warehouses و Data Lakes
# - اختيار محركات التخزين المناسبة بناءً على حجم البيانات
# - فهم مفاهيم Partitioning و Indexing
# </div>

# %% [markdown]
# <div dir="rtl">
# ## 1. تهيئة بيئة العمل وتثبيت المكتبات
# نقوم أولاً بالتحقق من المكتبات الأساسية.
# </div>

# %%
# TODO: أكمل الكود لتثبيت matplotlib و numpy
# !pip install matplotlib numpy
import numpy as np
import matplotlib.pyplot as plt
print('تم استيراد المكتبات بنجاح!')

# %% [markdown]
# <div dir="rtl">
# ## 2. الحل النموذجي للتحدي البرمجي
# الكود أدناه يمثل الحل النموذجي لتهيئة المخططات وحل مشكلة النصوص العربية.
# </div>

# %%
# إعدادات Matplotlib لإخراج SVG
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
plt.rcParams['svg.fonttype'] = 'none'

# رسم مخطط بسيط
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Sin Wave Chart')
plt.show()

# %% [markdown]
# <div dir="rtl">
# ## 3. المشروع التطبيقي للدرس (Project Challenge)
# **المطلوب:** تطبيق المفاهيم التي تم دراستها وبناء خوارزمية كاملة لحل المشكلة.
# </div>

# %%
# اكتب الكود الخاص بك هنا لحل التحدي التطبيقي
# def custom_solution():
#     pass
