# %% [markdown]
# <div dir="rtl">
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hanenalmayouf/Content-creator-dashdoard/blob/main/lessons/w1d3/w1d3_lab.ipynb)
#
# # هندسة البيانات في بيئات الإنتاج (MLOps & Data Ops)
# ### دمج ممارسات DataOps مع MLOps لأتمتة دورة حياة نماذج الذكاء الاصطناعي وضمان الاستمرارية (CI/CD/CT).
# </div>

# %% [markdown]
# <div dir="rtl"># معمل هندسة البيانات والذكاء الاصطناعي (MLOps & DataOps)
# أهلاً بكم في ورشة العمل التفاعلية. سنقوم اليوم ببناء خط أنابيب متكامل (Pipeline) يربط بين استيعاب البيانات، التدريب المؤتمت، والنشر في بيئة Kubernetes افتراضية.</div>

# %%
# استيراد المكتبات الأساسية لمحاكاة خط أنابيب البيانات
import pandas as pd
import numpy as np
from datetime import datetime

# محاكاة استيعاب البيانات الخام (Data Ingestion)
def ingest_data():
    print(f"[{datetime.now()}] بدء استيعاب البيانات من المصدر...")
    data = pd.DataFrame({'feature1': np.random.rand(100), 'target': np.random.randint(0, 2, 100)})
    return data

raw_data = ingest_data()
print("تم استيعاب البيانات بنجاح.")

# %% [markdown]
# <div dir="rtl">## التمرين العملي: أتمتة إعادة التدريب (Automated Retraining)
# في هذا الجزء، سنقوم بكتابة دالة تقوم بالتحقق من دقة النموذج، وإذا انخفضت عن حد معين، يتم تفعيل عملية إعادة التدريب.</div>

# %%
# تمرين: أكمل الكود التالي للتحقق من أداء النموذج
# TODO: قم بحساب دقة النموذج (Accuracy) وإذا كانت أقل من 0.7 قم بطباعة "إعادة تدريب مطلوبة"

def check_model_performance(accuracy):
    # اكتب الكود الخاص بك هنا
    pass

check_model_performance(0.65)

# %%
# الحل النموذجي للتمرين
def check_model_performance(accuracy):
    threshold = 0.7
    if accuracy < threshold:
        print(f"الدقة الحالية {accuracy}: إعادة تدريب مطلوبة (Triggering Retraining Pipeline)")
    else:
        print(f"الدقة الحالية {accuracy}: النموذج يعمل بكفاءة.")

check_model_performance(0.65)

# %% [markdown]
# <div dir="rtl">## مشروع التحدي (Project Challenge)
# المطلوب منك الآن:
# 1. بناء دالة تقوم بمحاكاة نشر النموذج (Deployment) في حاوية Docker.
# 2. إضافة آلية مراقبة (Monitoring) تقوم بتسجيل وقت الاستجابة (Latency) في ملف سجلات (Log file).
# 3. قم بمراجعة كود زميلك (Peer Review) للتأكد من اتباع معايير الكود النظيف (Clean Code).</div>

# %%
# هيكل مقترح للمشروع التطبيقي
import time

def deploy_model_to_k8s(model_name):
    print(f"جاري نشر النموذج {model_name} إلى بيئة Kubernetes...")
    time.sleep(1) # محاكاة وقت النشر
    print("تم النشر بنجاح.")

# ابدأ بتنفيذ التحدي هنا
deploy_model_to_k8s("Production_Model_v1")
